# %%
import keras
from keras.datasets import mnist
from keras.utils import to_categorical
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import accuracy_score
import pandas as pd
import matplotlib.pyplot as plt
# fix random seed for reproducibility
np.random.seed(7)

# %%
(x_train_origin, y_train_origin),(x_test_origin, y_test_origin) = mnist.load_data()
num_class = 10

# %%
x_train = x_train_origin.reshape((60000, 28 * 28))
x_train = x_train.astype('float32') / 255

x_test = x_test_origin.reshape((10000, 28 * 28))
x_test = x_test.astype('float32') / 255

# %%
y_train = to_categorical(y_train_origin, num_classes=10) 
y_test = to_categorical(y_test_origin, num_classes=10)

# %%
# create model
model = Sequential()
model.add(Dense(10, input_dim=784, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='SGD', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=20, batch_size=1000, validation_data=(x_test,y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 1s 10us/step - loss: 2.1373 - acc: 0.2524 - val_loss: 1.8627 - val_acc: 0.5039
# Epoch 2/20
# 60000/60000 [==============================] - 0s 6us/step - loss: 1.6863 - acc: 0.5969 - val_loss: 1.5067 - val_acc: 0.6784
# Epoch 3/20
# 60000/60000 [==============================] - 0s 8us/step - loss: 1.4026 - acc: 0.7039 - val_loss: 1.2765 - val_acc: 0.7398
# Epoch 4/20
# 60000/60000 [==============================] - 1s 9us/step - loss: 1.2150 - acc: 0.7512 - val_loss: 1.1204 - val_acc: 0.7746
# Epoch 5/20
# 60000/60000 [==============================] - 1s 9us/step - loss: 1.0844 - acc: 0.7776 - val_loss: 1.0091 - val_acc: 0.7962
# Epoch 6/20
# 60000/60000 [==============================] - 0s 7us/step - loss: 0.9891 - acc: 0.7948 - val_loss: 0.9261 - val_acc: 0.8112
# Epoch 7/20
# 60000/60000 [==============================] - 0s 7us/step - loss: 0.9167 - acc: 0.8074 - val_loss: 0.8620 - val_acc: 0.8234
# Epoch 8/20
# 60000/60000 [==============================] - 0s 7us/step - loss: 0.8598 - acc: 0.8159 - val_loss: 0.8109 - val_acc: 0.8319
# Epoch 9/20
# 60000/60000 [==============================] - 0s 7us/step - loss: 0.8139 - acc: 0.8232 - val_loss: 0.7692 - val_acc: 0.8370
# Epoch 10/20
# 60000/60000 [==============================] - 1s 10us/step - loss: 0.7759 - acc: 0.8288 - val_loss: 0.7344 - val_acc: 0.8438
# Epoch 11/20
# 60000/60000 [==============================] - 0s 8us/step - loss: 0.7440 - acc: 0.8341 - val_loss: 0.7050 - val_acc: 0.8477
# Epoch 12/20
# 60000/60000 [==============================] - 0s 8us/step - loss: 0.7168 - acc: 0.8382 - val_loss: 0.6798 - val_acc: 0.8509
# Epoch 13/20
# 60000/60000 [==============================] - 0s 8us/step - loss: 0.6932 - acc: 0.8422 - val_loss: 0.6578 - val_acc: 0.8537
# Epoch 14/20
# 60000/60000 [==============================] - 0s 8us/step - loss: 0.6726 - acc: 0.8452 - val_loss: 0.6385 - val_acc: 0.8569
# Epoch 15/20
# 60000/60000 [==============================] - 1s 9us/step - loss: 0.6544 - acc: 0.8479 - val_loss: 0.6214 - val_acc: 0.8593
# Epoch 16/20
# 60000/60000 [==============================] - 0s 8us/step - loss: 0.6382 - acc: 0.8505 - val_loss: 0.6062 - val_acc: 0.8609
# Epoch 17/20
# 60000/60000 [==============================] - 0s 8us/step - loss: 0.6237 - acc: 0.8527 - val_loss: 0.5924 - val_acc: 0.8625
# Epoch 18/20
# 60000/60000 [==============================] - 0s 8us/step - loss: 0.6106 - acc: 0.8549 - val_loss: 0.5800 - val_acc: 0.8643
# Epoch 19/20
# 60000/60000 [==============================] - 1s 9us/step - loss: 0.5986 - acc: 0.8569 - val_loss: 0.5687 - val_acc: 0.8656
# Epoch 20/20
# 60000/60000 [==============================] - 0s 7us/step - loss: 0.5877 - acc: 0.8584 - val_loss: 0.5583 - val_acc: 0.8675

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
